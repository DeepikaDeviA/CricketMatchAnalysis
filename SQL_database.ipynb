# %%
#import all necessary library
import mysql.connector
import pandas as pd
import numpy as np 
import os 
import json

# %%
# --- Reusable Cleanup Function ---
def clean_and_select_dataframe(df, desired_columns=None, df_name=""):
    
    # Convert column names to lowercase first
    df.columns = df.columns.str.lower()

    # Apply specific column selection if desired_columns are provided
    if desired_columns:
        actual_desired_cols = [col for col in desired_columns if col in df.columns]
        if len(actual_desired_cols) < len(desired_columns):
            missing_cols = set(desired_columns) - set(actual_desired_cols)
            print(f"Warning: For {df_name}, some desired columns were not found: {missing_cols}")
        
        df = df.loc[:, actual_desired_cols].copy() 
    
    # Strip whitespace from all string columns
    for col in df.select_dtypes(include='object').columns:
        
        df.loc[:, col] = df[col].astype(str).str.strip()

    # Replace common empty/placeholder strings with NaN for robust empty column detection
    
    df.replace(["", "NA", "-", "N/A", "NULL", "None"], np.nan, inplace=True) 

    # Remove 'Unnamed:' columns (if any remain after explicit selection or for other DFs)
    unnamed_cols = [col for col in df.columns if 'unnamed:' in str(col).lower()]
    if unnamed_cols:
        print(f"Dropping 'Unnamed:' columns from {df_name}: {unnamed_cols}")
        df.drop(columns=unnamed_cols, inplace=True)

    # Remove columns that are entirely empty (all NaN values)
    empty_cols = [col for col in df.columns if df[col].isnull().all()]
    if empty_cols:
        print(f"Dropping entirely empty columns from {df_name}: {empty_cols}")
        df.drop(columns=empty_cols, inplace=True)

    # Drop rows where all values are NaN (if an entire row is empty after column cleanup)
    df.dropna(how="all", inplace=True)
    
    #Perform numeric conversion BEFORE filling remaining NaNs with "NA" string ---
    
    num_cols = df.select_dtypes(include=["int64", "float64"]).columns
   
    df.loc[:, num_cols] = df[num_cols].apply(lambda col: pd.to_numeric(col, errors="coerce").fillna(0).astype(int))

    # After numeric conversions, fill any remaining NaNs (which would be in non-numeric columns)
    
    df.fillna("NA", inplace=True) 
    
    return df

# %%
# Define Desired Columns for Each Table (matching the updated schema)

# Common summary columns for ODI, Test
COMMON_SUMMARY_COLS = [
    "match_id", "match_format", "date", "city", "venue", "season", "gender",
    "team_1", "team_2", "toss_winner", "toss_decision", "winner",
    "win_by_runs", "win_by_wickets", "overs", "balls_per_over", "player_of_match"
]

# T20 and IPL summary columns
T20_IPL_SUMMARY_COLS = [
    "match_id", "match_format", "date", "city", "venue", "season", "gender",
    "team_1", "team_2", "toss_winner", "toss_decision", "winner",
    "win_by_runs", "win_by_wickets", "overs", "balls_per_over", "player_of_match",
    "target_runs", "target_overs", "powerplays"
]

# Test summary columns
TEST_SUMMARY_COLS = [
    "match_id", "match_format", "start_date", "end_date", "city", "venue",
    "gender", "season", "team_1", "team_2", "toss_winner", "toss_decision",
    "winner", "win_by_runs", "win_by_wickets", "balls_per_over", "player_of_match"
]

# Common ball-by-ball columns for ODI, Test
COMMON_BALL_BY_BALL_COLS = [
    "match_id", "inning_team", "over_number", "batter", "non_striker",
    "bowler", "legbyes", "wides", "no_balls", "byes", "runs_batter",
    "runs_extras", "runs_total", "wicket_kind", "player_out"
]

# Ball-by-ball columns for T20, IPL
T20_IPL_BALL_BY_BALL_COLS = [
    "match_id", "inning_team", "over_number", "batter", "non_striker",
    "bowler", "legbyes", "wides", "no_balls", "byes", "runs_batter",
    "runs_extras", "runs_total", "wicket_kind", "player_out"
]

# Player Registry columns
PLAYER_REGISTRY_COLS = [
    "match_id", "player_name", "player_id"
]

# %%
# Connect to TiDB Cloud
conn = mysql.connector.connect(
    host="gateway01.ap-southeast-1.prod.aws.tidbcloud.com",
    user="4DTwJ2ZR7XTapss.root",
    password="veNd2wXPKzLZwbmt",
    port=4000
)
cursor = conn.cursor()

# Create Database
cursor.execute('''CREATE DATABASE IF NOT EXISTS cricket_data''')
cursor.execute('''USE cricket_data''')

# %%
# Match Summary Tables
cursor.execute(f"""
CREATE TABLE IF NOT EXISTS odi_match_summary (
    match_id VARCHAR(100) PRIMARY KEY,
    match_format VARCHAR(20),
    date DATE,
    city VARCHAR(100),
    venue VARCHAR(200),
    season VARCHAR(10),
    gender VARCHAR(10),
    team_1 VARCHAR(100),
    team_2 VARCHAR(100),
    toss_winner VARCHAR(100),
    toss_decision VARCHAR(20),
    winner VARCHAR(100),
    win_by_runs INT,
    win_by_wickets INT,
    overs INT,
    balls_per_over INT,
    player_of_match VARCHAR(100)
);
""")

cursor.execute(f"""
CREATE TABLE IF NOT EXISTS t20_match_summary (
    match_id VARCHAR(100) PRIMARY KEY,
    match_format VARCHAR(20),
    date DATE,
    city VARCHAR(100),
    venue VARCHAR(200),
    season VARCHAR(10),
    gender VARCHAR(10),
    team_1 VARCHAR(100),
    team_2 VARCHAR(100),
    toss_winner VARCHAR(100),
    toss_decision VARCHAR(20),
    winner VARCHAR(100),
    win_by_runs INT,
    win_by_wickets INT,
    overs INT,
    balls_per_over INT,
    player_of_match VARCHAR(100),
    target_runs INT, 
    target_overs FLOAT,
    powerplays VARCHAR(500) 
);
""")

cursor.execute(f"""
CREATE TABLE IF NOT EXISTS ipl_match_summary (
    match_id VARCHAR(100) PRIMARY KEY,
    match_format VARCHAR(20),
    date DATE,
    city VARCHAR(100),
    venue VARCHAR(200),
    season VARCHAR(10),
    gender VARCHAR(10),
    team_1 VARCHAR(100),
    team_2 VARCHAR(100),
    toss_winner VARCHAR(100),
    toss_decision VARCHAR(20),
    winner VARCHAR(100),
    win_by_runs INT,
    win_by_wickets INT,
    overs INT,
    balls_per_over INT,
    player_of_match VARCHAR(100),
    target_runs INT, 
    target_overs FLOAT,
    powerplays VARCHAR(500)
);
""")

cursor.execute(f"""
CREATE TABLE IF NOT EXISTS test_match_summary (
    match_id VARCHAR(100) PRIMARY KEY,
    match_format VARCHAR(20),
    start_date DATE,
    end_date DATE,
    city VARCHAR(100),
    venue VARCHAR(200),
    gender VARCHAR(10),
    season VARCHAR(10),
    team_1 VARCHAR(100),
    team_2 VARCHAR(100),
    toss_winner VARCHAR(100),
    toss_decision VARCHAR(20),
    winner VARCHAR(100),
    win_by_runs INT,
    win_by_wickets INT,
    balls_per_over INT,
    player_of_match VARCHAR(100)
);
""")

# --- Ball-by-ball Table Structures ---
cursor.execute(f"""
CREATE TABLE IF NOT EXISTS odi_ball_by_ball (
    match_id VARCHAR(100),
    inning_team VARCHAR(100),
    over_number FLOAT,
    batter VARCHAR(100),
    non_striker VARCHAR(100),
    bowler VARCHAR(100),
    legbyes INT,
    wides INT,
    no_balls INT,
    byes INT,
    runs_batter INT,
    runs_extras INT,
    runs_total INT,
    wicket_kind VARCHAR(50),
    player_out VARCHAR(100)
);
""")

cursor.execute(f"""
CREATE TABLE IF NOT EXISTS test_ball_by_ball (
    match_id VARCHAR(100),
    inning_team VARCHAR(100),
    over_number FLOAT,
    batter VARCHAR(100),
    non_striker VARCHAR(100),
    bowler VARCHAR(100),
    legbyes INT,
    wides INT,
    no_balls INT,
    byes INT,
    runs_batter INT,
    runs_extras INT,
    runs_total INT,
    wicket_kind VARCHAR(50),
    player_out VARCHAR(100)
);
""")

cursor.execute(f"""
CREATE TABLE IF NOT EXISTS t20_ball_by_ball (
    match_id VARCHAR(100),
    inning_team VARCHAR(100),
    over_number FLOAT,
    batter VARCHAR(100),
    non_striker VARCHAR(100),
    bowler VARCHAR(100),
    legbyes INT,
    wides INT,
    no_balls INT,
    byes INT,
    runs_batter INT,
    runs_extras INT,
    runs_total INT,
    wicket_kind VARCHAR(50),
    player_out VARCHAR(100)
);
""")

cursor.execute(f"""
CREATE TABLE IF NOT EXISTS ipl_ball_by_ball (
    match_id VARCHAR(100),
    inning_team VARCHAR(100),
    over_number FLOAT,
    batter VARCHAR(100),
    non_striker VARCHAR(100),
    bowler VARCHAR(100),
    legbyes INT,
    wides INT,
    no_balls INT,
    byes INT,
    runs_batter INT,
    runs_extras INT,
    runs_total INT,
    wicket_kind VARCHAR(50),
    player_out VARCHAR(100)
    
);
""")

# Player Registry Table
cursor.execute(f"""
CREATE TABLE IF NOT EXISTS player_registry (
    match_id VARCHAR(100),
    player_name VARCHAR(100),
    player_id VARCHAR(100),
    PRIMARY KEY (match_id, player_name)
);
""")

conn.commit()
print("✅ All tables created successfully.")
# Out:
# ✅ All tables created successfully.

# %%
# Now Upload CSV Data in Batches
def insert_batchwise(df, table_name, batch_size=500):
    if df.empty:
        print(f"Skipping insertion for {table_name}: DataFrame is empty.")
        return

    columns = ", ".join(df.columns)
    # Ensure placeholders match the number of columns in the DataFrame
    placeholders = ", ".join(["%s"] * len(df.columns))
    query = f"INSERT INTO {table_name} ({columns}) VALUES ({placeholders})"

    print(f"Starting batch insertion into {table_name}...")
    for i in range(0, len(df), batch_size):
        batch = df.iloc[i:i+batch_size].values.tolist()
        try:
            cursor.executemany(query, batch)
            conn.commit()
            print(f"Inserted batch {i//batch_size + 1}/{len(df)//batch_size + (1 if len(df)%batch_size > 0 else 0)} ({len(batch)} rows) into {table_name}")
        except mysql.connector.Error as err:
            print(f"Error inserting batch into {table_name} (batch {i//batch_size + 1}): {err}")
            conn.rollback() # Rollback on error to prevent partial inserts

# %%
# Map CSV files to their corresponding table names and desired columns
csv_to_table_mapping = {
    "odi_match_summary.csv": {"table": "odi_match_summary", "cols": COMMON_SUMMARY_COLS, "date_cols": ["date"]},
    "t20_match_summary.csv": {"table": "t20_match_summary", "cols": T20_IPL_SUMMARY_COLS, "date_cols": ["date"]},
    "ipl_match_summary.csv": {"table": "ipl_match_summary", "cols": T20_IPL_SUMMARY_COLS, "date_cols": ["date"]},
    "test_match_summary.csv": {"table": "test_match_summary", "cols": TEST_SUMMARY_COLS, "date_cols": ["start_date", "end_date"]},
    "odi_ball_by_ball.csv": {"table": "odi_ball_by_ball", "cols": COMMON_BALL_BY_BALL_COLS, "date_cols": []},
    "t20_ball_by_ball.csv": {"table": "t20_ball_by_ball", "cols": T20_IPL_BALL_BY_BALL_COLS, "date_cols": []},
    "ipl_ball_by_ball.csv": {"table": "ipl_ball_by_ball", "cols": T20_IPL_BALL_BY_BALL_COLS, "date_cols": []},
    "test_ball_by_ball.csv": {"table": "test_ball_by_ball", "cols": COMMON_BALL_BY_BALL_COLS, "date_cols": []},
    "player_registry.csv": {"table": "player_registry", "cols": PLAYER_REGISTRY_COLS, "date_cols": []}
}

# Upload all CSVs
for csv_file, details in csv_to_table_mapping.items():
    table_name = details["table"]
    desired_columns = details["cols"]
    date_columns = details["date_cols"]

    try:
        if not os.path.exists(csv_file):
            print(f"CSV file not found: {csv_file}. Skipping.")
            continue

        df = pd.read_csv(csv_file)
        
        # Apply the comprehensive cleanup and column selection
        df = clean_and_select_dataframe(df, desired_columns=desired_columns, df_name=csv_file)

        # Handle date column conversion (specific to summary tables)
        for date_col in date_columns:
            if date_col in df.columns:
                # Convert 'NA' string back to NaN for datetime conversion
                df[date_col] = df[date_col].replace("NA", np.nan)
                df[date_col] = pd.to_datetime(df[date_col], errors="coerce")
                # Convert NaT (Not a Time) back to None or specific placeholder for database
                # MySQL connector often handles None as NULL, which is appropriate for DATE columns
                df[date_col] = df[date_col].replace({pd.NaT: None}) 
        
        insert_batchwise(df, table_name, batch_size=500)

    except Exception as e:
        print(f"Failed to process and insert {csv_file} into {table_name}: {e}")

cursor.close()
conn.close()
print("\n All available CSV data processed and uploaded to TiDB.")
# Out:
# Starting batch insertion into odi_match_summary...
# Inserted batch 1/6 (500 rows) into odi_match_summary
# Inserted batch 2/6 (500 rows) into odi_match_summary
# Inserted batch 3/6 (500 rows) into odi_match_summary
# Inserted batch 4/6 (500 rows) into odi_match_summary
# Inserted batch 5/6 (500 rows) into odi_match_summary
# Inserted batch 6/6 (486 rows) into odi_match_summary
# Starting batch insertion into t20_match_summary...
# Inserted batch 1/9 (500 rows) into t20_match_summary
# Inserted batch 2/9 (500 rows) into t20_match_summary
# Inserted batch 3/9 (500 rows) into t20_match_summary
# Inserted batch 4/9 (500 rows) into t20_match_summary
# Inserted batch 5/9 (500 rows) into t20_match_summary
# Inserted batch 6/9 (500 rows) into t20_match_summary
# Inserted batch 7/9 (500 rows) into t20_match_summary
# Inserted batch 8/9 (500 rows) into t20_match_summary
# Inserted batch 9/9 (468 rows) into t20_match_summary
# Starting batch insertion into ipl_match_summary...
# Inserted batch 1/3 (500 rows) into ipl_match_summary
# Inserted batch 2/3 (500 rows) into ipl_match_summary
# Inserted batch 3/3 (169 rows) into ipl_match_summary
# Starting batch insertion into test_match_summary...
# Inserted batch 1/2 (500 rows) into test_match_summary
# Inserted batch 2/2 (375 rows) into test_match_summary
# Starting batch insertion into odi_ball_by_ball...
# Inserted batch 1/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 2/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 3/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 4/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 5/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 6/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 7/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 8/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 9/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 10/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 11/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 12/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 13/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 14/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 15/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 16/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 17/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 18/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 19/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 20/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 21/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 22/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 23/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 24/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 25/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 26/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 27/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 28/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 29/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 30/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 31/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 32/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 33/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 34/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 35/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 36/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 37/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 38/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 39/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 40/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 41/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 42/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 43/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 44/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 45/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 46/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 47/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 48/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 49/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 50/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 51/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 52/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 53/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 54/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 55/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 56/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 57/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 58/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 59/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 60/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 61/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 62/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 63/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 64/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 65/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 66/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 67/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 68/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 69/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 70/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 71/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 72/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 73/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 74/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 75/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 76/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 77/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 78/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 79/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 80/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 81/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 82/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 83/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 84/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 85/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 86/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 87/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 88/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 89/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 90/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 91/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 92/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 93/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 94/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 95/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 96/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 97/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 98/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 99/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 100/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 101/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 102/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 103/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 104/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 105/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 106/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 107/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 108/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 109/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 110/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 111/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 112/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 113/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 114/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 115/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 116/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 117/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 118/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 119/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 120/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 121/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 122/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 123/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 124/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 125/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 126/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 127/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 128/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 129/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 130/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 131/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 132/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 133/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 134/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 135/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 136/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 137/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 138/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 139/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 140/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 141/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 142/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 143/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 144/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 145/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 146/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 147/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 148/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 149/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 150/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 151/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 152/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 153/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 154/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 155/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 156/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 157/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 158/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 159/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 160/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 161/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 162/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 163/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 164/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 165/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 166/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 167/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 168/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 169/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 170/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 171/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 172/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 173/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 174/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 175/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 176/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 177/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 178/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 179/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 180/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 181/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 182/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 183/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 184/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 185/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 186/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 187/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 188/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 189/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 190/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 191/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 192/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 193/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 194/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 195/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 196/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 197/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 198/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 199/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 200/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 201/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 202/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 203/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 204/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 205/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 206/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 207/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 208/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 209/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 210/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 211/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 212/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 213/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 214/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 215/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 216/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 217/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 218/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 219/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 220/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 221/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 222/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 223/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 224/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 225/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 226/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 227/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 228/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 229/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 230/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 231/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 232/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 233/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 234/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 235/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 236/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 237/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 238/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 239/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 240/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 241/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 242/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 243/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 244/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 245/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 246/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 247/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 248/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 249/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 250/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 251/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 252/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 253/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 254/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 255/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 256/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 257/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 258/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 259/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 260/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 261/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 262/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 263/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 264/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 265/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 266/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 267/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 268/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 269/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 270/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 271/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 272/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 273/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 274/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 275/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 276/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 277/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 278/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 279/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 280/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 281/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 282/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 283/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 284/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 285/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 286/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 287/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 288/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 289/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 290/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 291/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 292/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 293/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 294/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 295/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 296/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 297/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 298/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 299/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 300/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 301/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 302/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 303/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 304/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 305/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 306/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 307/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 308/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 309/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 310/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 311/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 312/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 313/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 314/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 315/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 316/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 317/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 318/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 319/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 320/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 321/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 322/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 323/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 324/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 325/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 326/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 327/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 328/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 329/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 330/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 331/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 332/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 333/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 334/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 335/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 336/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 337/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 338/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 339/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 340/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 341/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 342/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 343/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 344/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 345/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 346/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 347/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 348/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 349/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 350/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 351/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 352/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 353/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 354/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 355/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 356/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 357/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 358/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 359/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 360/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 361/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 362/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 363/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 364/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 365/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 366/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 367/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 368/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 369/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 370/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 371/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 372/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 373/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 374/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 375/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 376/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 377/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 378/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 379/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 380/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 381/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 382/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 383/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 384/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 385/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 386/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 387/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 388/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 389/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 390/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 391/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 392/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 393/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 394/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 395/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 396/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 397/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 398/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 399/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 400/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 401/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 402/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 403/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 404/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 405/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 406/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 407/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 408/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 409/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 410/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 411/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 412/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 413/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 414/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 415/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 416/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 417/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 418/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 419/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 420/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 421/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 422/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 423/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 424/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 425/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 426/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 427/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 428/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 429/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 430/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 431/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 432/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 433/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 434/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 435/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 436/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 437/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 438/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 439/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 440/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 441/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 442/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 443/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 444/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 445/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 446/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 447/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 448/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 449/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 450/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 451/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 452/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 453/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 454/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 455/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 456/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 457/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 458/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 459/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 460/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 461/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 462/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 463/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 464/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 465/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 466/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 467/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 468/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 469/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 470/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 471/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 472/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 473/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 474/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 475/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 476/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 477/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 478/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 479/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 480/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 481/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 482/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 483/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 484/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 485/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 486/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 487/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 488/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 489/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 490/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 491/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 492/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 493/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 494/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 495/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 496/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 497/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 498/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 499/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 500/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 501/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 502/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 503/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 504/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 505/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 506/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 507/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 508/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 509/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 510/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 511/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 512/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 513/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 514/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 515/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 516/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 517/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 518/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 519/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 520/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 521/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 522/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 523/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 524/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 525/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 526/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 527/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 528/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 529/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 530/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 531/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 532/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 533/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 534/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 535/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 536/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 537/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 538/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 539/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 540/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 541/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 542/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 543/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 544/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 545/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 546/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 547/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 548/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 549/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 550/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 551/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 552/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 553/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 554/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 555/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 556/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 557/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 558/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 559/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 560/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 561/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 562/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 563/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 564/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 565/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 566/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 567/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 568/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 569/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 570/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 571/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 572/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 573/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 574/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 575/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 576/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 577/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 578/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 579/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 580/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 581/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 582/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 583/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 584/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 585/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 586/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 587/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 588/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 589/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 590/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 591/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 592/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 593/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 594/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 595/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 596/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 597/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 598/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 599/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 600/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 601/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 602/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 603/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 604/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 605/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 606/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 607/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 608/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 609/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 610/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 611/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 612/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 613/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 614/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 615/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 616/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 617/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 618/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 619/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 620/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 621/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 622/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 623/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 624/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 625/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 626/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 627/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 628/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 629/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 630/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 631/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 632/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 633/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 634/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 635/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 636/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 637/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 638/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 639/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 640/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 641/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 642/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 643/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 644/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 645/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 646/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 647/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 648/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 649/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 650/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 651/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 652/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 653/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 654/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 655/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 656/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 657/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 658/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 659/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 660/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 661/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 662/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 663/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 664/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 665/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 666/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 667/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 668/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 669/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 670/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 671/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 672/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 673/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 674/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 675/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 676/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 677/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 678/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 679/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 680/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 681/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 682/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 683/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 684/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 685/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 686/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 687/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 688/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 689/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 690/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 691/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 692/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 693/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 694/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 695/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 696/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 697/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 698/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 699/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 700/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 701/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 702/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 703/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 704/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 705/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 706/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 707/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 708/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 709/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 710/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 711/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 712/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 713/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 714/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 715/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 716/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 717/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 718/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 719/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 720/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 721/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 722/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 723/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 724/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 725/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 726/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 727/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 728/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 729/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 730/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 731/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 732/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 733/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 734/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 735/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 736/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 737/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 738/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 739/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 740/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 741/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 742/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 743/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 744/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 745/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 746/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 747/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 748/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 749/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 750/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 751/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 752/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 753/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 754/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 755/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 756/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 757/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 758/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 759/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 760/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 761/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 762/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 763/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 764/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 765/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 766/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 767/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 768/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 769/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 770/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 771/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 772/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 773/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 774/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 775/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 776/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 777/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 778/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 779/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 780/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 781/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 782/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 783/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 784/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 785/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 786/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 787/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 788/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 789/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 790/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 791/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 792/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 793/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 794/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 795/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 796/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 797/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 798/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 799/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 800/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 801/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 802/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 803/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 804/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 805/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 806/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 807/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 808/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 809/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 810/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 811/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 812/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 813/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 814/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 815/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 816/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 817/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 818/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 819/3163 (500 rows) into odi_ball_by_ball
# Inserted batch 820/3163 (500 rows) into odi_ball_by_ball
# ...
# Inserted batch 3136/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3137/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3138/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3139/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3140/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3141/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3142/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3143/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3144/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3145/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3146/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3147/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3148/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3149/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3150/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3151/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3152/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3153/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3154/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3155/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3156/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3157/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3158/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3159/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3160/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3161/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3162/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3163/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3164/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3165/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3166/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3167/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3168/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3169/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3170/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3171/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3172/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3173/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3174/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3175/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3176/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3177/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3178/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3179/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3180/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3181/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3182/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3183/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3184/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3185/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3186/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3187/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3188/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3189/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3190/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3191/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3192/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3193/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3194/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3195/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3196/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3197/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3198/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3199/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3200/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3201/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3202/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3203/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3204/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3205/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3206/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3207/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3208/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3209/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3210/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3211/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3212/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3213/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3214/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3215/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3216/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3217/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3218/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3219/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3220/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3221/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3222/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3223/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3224/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3225/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3226/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3227/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3228/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3229/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3230/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3231/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3232/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3233/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3234/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3235/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3236/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3237/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3238/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3239/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3240/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3241/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3242/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3243/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3244/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3245/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3246/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3247/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3248/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3249/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3250/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3251/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3252/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3253/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3254/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3255/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3256/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3257/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3258/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3259/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3260/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3261/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3262/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3263/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3264/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3265/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3266/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3267/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3268/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3269/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3270/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3271/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3272/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3273/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3274/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3275/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3276/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3277/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3278/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3279/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3280/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3281/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3282/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3283/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3284/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3285/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3286/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3287/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3288/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3289/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3290/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3291/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3292/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3293/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3294/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3295/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3296/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3297/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3298/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3299/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3300/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3301/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3302/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3303/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3304/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3305/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3306/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3307/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3308/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3309/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3310/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3311/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3312/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3313/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3314/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3315/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3316/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3317/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3318/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3319/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3320/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3321/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3322/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3323/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3324/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3325/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3326/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3327/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3328/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3329/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3330/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3331/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3332/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3333/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3334/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3335/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3336/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3337/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3338/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3339/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3340/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3341/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3342/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3343/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3344/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3345/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3346/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3347/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3348/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3349/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3350/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3351/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3352/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3353/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3354/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3355/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3356/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3357/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3358/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3359/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3360/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3361/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3362/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3363/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3364/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3365/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3366/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3367/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3368/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3369/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3370/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3371/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3372/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3373/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3374/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3375/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3376/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3377/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3378/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3379/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3380/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3381/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3382/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3383/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3384/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3385/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3386/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3387/3388 (500 rows) into test_ball_by_ball
# Inserted batch 3388/3388 (34 rows) into test_ball_by_ball
# Starting batch insertion into player_registry...
# Inserted batch 1/18 (500 rows) into player_registry
# Inserted batch 2/18 (500 rows) into player_registry
# Inserted batch 3/18 (500 rows) into player_registry
# Inserted batch 4/18 (500 rows) into player_registry
# Inserted batch 5/18 (500 rows) into player_registry
# Inserted batch 6/18 (500 rows) into player_registry
# Inserted batch 7/18 (500 rows) into player_registry
# Inserted batch 8/18 (500 rows) into player_registry
# Inserted batch 9/18 (500 rows) into player_registry
# Inserted batch 10/18 (500 rows) into player_registry
# Inserted batch 11/18 (500 rows) into player_registry
# Inserted batch 12/18 (500 rows) into player_registry
# Inserted batch 13/18 (500 rows) into player_registry
# Inserted batch 14/18 (500 rows) into player_registry
# Inserted batch 15/18 (500 rows) into player_registry
# Inserted batch 16/18 (500 rows) into player_registry
# Inserted batch 17/18 (500 rows) into player_registry
# Inserted batch 18/18 (262 rows) into player_registry
#
#  All available CSV data processed and uploaded to TiDB.
